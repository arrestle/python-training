# %% [markdown]
# ### Bytes

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'

# %%
smileyBytes = bytes('🙄', 'utf-8')+bytes('1111','utf-8')
smileyBytes
# Out:
# b'\xf0\x9f\x99\x841111'

# %%
smileyBytes.decode('utf-8')
# Out:
# '🙄🙄'

# %%
smileyBytes = bytearray('🙄', 'utf-8')

# %%
smileyBytes
# Out:
# bytearray(b'\xf0\x9f\x99\x84')

# %%
smileyBytes[3] = int('87', 16)

# %%
smileyBytes.decode('utf-8')
# Out:
# '🙇'
